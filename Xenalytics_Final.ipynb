# %% [markdown]
# <a href="https://colab.research.google.com/github/JoelAlph/StockPrice_Prediction_Xenalytics/blob/main/Xenalytics_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Price Analysis : Xenalytics

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Datasets

# %%
lumina = pd.read_csv("/content/drive/MyDrive/Xenalytics /Lumina.csv", parse_dates=['Date'],index_col=["Date"])
nexus = pd.read_csv("/content/drive/MyDrive/Xenalytics /Nexus.csv",parse_dates=['Date'],index_col=["Date"])
quantumize = pd.read_csv("/content/drive/MyDrive/Xenalytics /Quantumize.csv",parse_dates=['Date'],index_col=["Date"])
synthify = pd.read_csv("/content/drive/MyDrive/Xenalytics /Synthify.csv",parse_dates=['Date'],index_col=["Date"])
zenith = pd.read_csv("/content/drive/MyDrive/Xenalytics /Zenith.csv",parse_dates=['Date'],index_col=["Date"])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
lumina.tail()
# Out:
#             Stock_Price
# Date
# 2024-02-11           82
# 2024-02-12           79
# 2024-02-13           82
# 2024-02-14           85
# 2024-02-15           88

# %%
lumina.dtypes
# Out:
# Stock_Price    int64
# dtype: object

# %%
plt.style.use('fivethirtyeight')
lumina.plot(figsize=(8,4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
nexus.plot(figsize=(8 ,4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
quantumize.plot(figsize=(8, 4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
zenith.plot(figsize=(8, 4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
synthify.plot(figsize=(8, 4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %% [markdown]
# ## Lumina Stock

# %%
timesteps = lumina.index.to_numpy()
prices = lumina["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([50, 53, 57, 52, 58, 55, 60, 56, 59, 62]))

# %% [markdown]
# ### Naive Base Model

# %%
split_size = int(0.8 * len(prices))

X_train, y_train = timesteps[:split_size], prices[:split_size]

X_test, y_test = timesteps[split_size:], prices[split_size:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (36, 10, 36, 10)

# %%
# Taken from Daniel Bourke GitHub repo for TIme Series BitCoin Prediction
def plot_time_series(timesteps, values, format='.', start=0, end=None, label=None):
  """
  Plots a timesteps (a series of points in time) against values (a series of values across timesteps).

  Parameters
  ---------
  timesteps : array of timesteps
  values : array of values across time
  format : style of plot, default "."
  start : where to start the plot (setting a value will index from start of timesteps & values)
  end : where to end the plot (setting a value will index from end of timesteps & values)
  label : label to show on plot of values
  """
  # Plot the series
  plt.plot(timesteps[start:end], values[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("StockPrice")
  if label:
    plt.legend(fontsize=14) # make label bigger
  plt.grid(True)

# %%
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_train, values=y_train, label="Train data")
plot_time_series(timesteps=X_test, values=y_test, label="Test data")

# %%
# Create a naïve forecast
naive_forecast = y_test[:-1]
naive_forecast[:10], naive_forecast[-10:]
# Out:
# (array([78, 81, 85, 88, 85, 82, 79, 82, 85]),
#  array([78, 81, 85, 88, 85, 82, 79, 82, 85]))

# %%
# Plot naive forecast
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_train, values=y_train, label="Train data")
plot_time_series(timesteps=X_test, values=y_test, label="Test data")
plot_time_series(timesteps=X_test[1:], values=naive_forecast, format="-", label="Naive forecast");

# %%
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1]))

  return mae / mae_naive_no_season

# %%
# Taken from Daniel Bourke GitHub repo for TIme Series BitCoin Prediction
def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred) # puts and emphasis on outliers (all errors get squared)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true, y_pred)

  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy(),
          "mase": mase.numpy()}

# %%
naive_results = evaluate_preds(y_true=y_test[1:],
                               y_pred=naive_forecast)
naive_results
# Out:
# {'mae': 3.1111112,
#  'mse': 9.777778,
#  'rmse': 3.1269438,
#  'mape': 3.711237,
#  'mase': 0.9955556}

# %% [markdown]
# ### Windowing dataset

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
# Taken from Daniel Bourke GitHub repo for TIme Series BitCoin Prediction
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.

  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %%
# Test out the window labelling function
test_window, test_label = get_labelled_windows(tf.expand_dims(tf.range(8)+1, axis=0), horizon=HORIZON)
print(f"Window: {tf.squeeze(test_window).numpy()} -> Label: {tf.squeeze(test_label).numpy()}")
# Out:
# Window: [1 2 3 4 5 6 7] -> Label: 8

# %%
# Taken from Daniel Bourke GitHub repo for TIme Series BitCoin Prediction
def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  # 1. Create a window of specific window_size (add the horizon on the end for later labelling)
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  # print(f"Window step:\n {window_step}")

  # 2. Create a 2D array of multiple window steps (minus 1 to account for 0 indexing)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T # create 2D array of windows of size window_size
  # print(f"Window indexes:\n {window_indexes[:3], window_indexes[-3:], window_indexes.shape}")

  # 3. Index on the target array (time series) with 2D array of multiple window steps
  windowed_array = x[window_indexes]

  # 4. Get the labelled windows
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %%
import numpy as np
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [50 53 57 52 58 55 60] -> Label: [56]
# Window: [53 57 52 58 55 60 56] -> Label: [59]
# Window: [57 52 58 55 60 56 59] -> Label: [62]

# %%
# View the last 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i-3]} -> Label: {full_labels[i-3]}")
# Out:
# Window: [78 81 85 88 85 82 79] -> Label: [82]
# Window: [81 85 88 85 82 79 82] -> Label: [85]
# Window: [85 88 85 82 79 82 85] -> Label: [88]

# %%
# Make the train/test splits (Taken from Daniel Bourke GitHub repo for TIme Series BitCoin Prediction)
def make_train_test_splits(windows, labels, test_split=0.2):
  """
  Splits matching pairs of windows and labels into train and test splits.
  """
  split_size = int(len(windows) * (1-test_split)) # this will default to 80% train/20% test
  train_windows = windows[:split_size]
  train_labels = labels[:split_size]
  test_windows = windows[split_size:]
  test_labels = labels[split_size:]
  return train_windows, test_windows, train_labels, test_labels

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1)) # add an extra dimension for timesteps
print(f"Original shape: {x.shape}") # (WINDOW_SIZE)
print(f"Expanded shape: {expand_dims_layer(x).shape}") # (WINDOW_SIZE, input_dim)
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[50]
#  [53]
#  [57]
#  [52]
#  [58]
#  [55]
#  [60]]

# %% [markdown]
# ### Modelling

# %%
import os
def create_model_checkpoint(model_name, save_path="model_experiments"):
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name),
                                            verbose=0,
                                            save_best_only=True)

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs) # expand input dimension to be compatible with LSTM
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x)
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model = tf.keras.Model(inputs=inputs, outputs=output, name="model_5_lstm")

# Compile model
model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Fit
model.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 2/2 [==============================] - 5s 2s/step - loss: 77.3288 - val_loss: 86.0324
# Epoch 2/50
# 2/2 [==============================] - 1s 1s/step - loss: 75.7220 - val_loss: 84.2335
# Epoch 3/50
# 2/2 [==============================] - 1s 1s/step - loss: 74.0710 - val_loss: 82.3061
# Epoch 4/50
# 2/2 [==============================] - 1s 1s/step - loss: 72.3379 - val_loss: 80.1426
# Epoch 5/50
# 2/2 [==============================] - 2s 2s/step - loss: 70.4053 - val_loss: 77.7733
# Epoch 6/50
# 2/2 [==============================] - 1s 1s/step - loss: 68.2417 - val_loss: 75.3175
# Epoch 7/50
# 2/2 [==============================] - 2s 2s/step - loss: 65.9495 - val_loss: 72.7318
# Epoch 8/50
# 2/2 [==============================] - 2s 2s/step - loss: 63.4579 - val_loss: 69.6238
# Epoch 9/50
# 2/2 [==============================] - 1s 1s/step - loss: 60.4539 - val_loss: 65.6096
# Epoch 10/50
# 2/2 [==============================] - 2s 2s/step - loss: 56.8390 - val_loss: 60.9708
# Epoch 11/50
# 2/2 [==============================] - 1s 1s/step - loss: 52.8780 - val_loss: 56.3260
# Epoch 12/50
# 2/2 [==============================] - 1s 1s/step - loss: 49.0149 - val_loss: 51.7315
# Epoch 13/50
# 2/2 [==============================] - 1s 1s/step - loss: 45.0534 - val_loss: 47.1873
# Epoch 14/50
# 2/2 [==============================] - 1s 1s/step - loss: 41.1269 - val_loss: 42.9465
# Epoch 15/50
# 2/2 [==============================] - 2s 2s/step - loss: 37.4612 - val_loss: 38.9310
# Epoch 16/50
# 2/2 [==============================] - 2s 2s/step - loss: 33.9034 - val_loss: 34.6162
# Epoch 17/50
# 2/2 [==============================] - 1s 1s/step - loss: 30.0021 - val_loss: 29.2380
# Epoch 18/50
# 2/2 [==============================] - 2s 2s/step - loss: 25.0054 - val_loss: 21.6831
# Epoch 19/50
# 2/2 [==============================] - 1s 1s/step - loss: 18.1272 - val_loss: 11.1361
# Epoch 20/50
# 2/2 [==============================] - 2s 2s/step - loss: 9.2653 - val_loss: 1.8062
# Epoch 21/50
# 2/2 [==============================] - 0s 29ms/step - loss: 4.5574 - val_loss: 8.1046
# Epoch 22/50
# 2/2 [==============================] - 0s 27ms/step - loss: 6.6684 - val_loss: 11.0906
# Epoch 23/50
# 2/2 [==============================] - 0s 26ms/step - loss: 8.7889 - val_loss: 11.4233
# Epoch 24/50
# 2/2 [==============================] - 0s 27ms/step - loss: 8.8434 - val_loss: 10.1885
# Epoch 25/50
# 2/2 [==============================] - 0s 26ms/step - loss: 7.5585 - val_loss: 7.9251
# Epoch 26/50
# 2/2 [==============================] - 0s 28ms/step - loss: 5.5012 - val_loss: 5.0021
# Epoch 27/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7819 - val_loss: 2.6430
# Epoch 28/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5336 - val_loss: 2.3575
# Epoch 29/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.9493 - val_loss: 2.9410
# Epoch 30/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.5450 - val_loss: 3.5656
# Epoch 31/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.7874 - val_loss: 3.4411
# Epoch 32/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.6114 - val_loss: 2.8127
# Epoch 33/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.0617 - val_loss: 2.4691
# Epoch 34/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8540 - val_loss: 2.3711
# Epoch 35/50
# 2/2 [==============================] - 0s 31ms/step - loss: 3.5711 - val_loss: 2.7306
# Epoch 36/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4522 - val_loss: 3.6891
# Epoch 37/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5873 - val_loss: 4.3670
# Epoch 38/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7657 - val_loss: 4.4801
# Epoch 39/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7569 - val_loss: 4.1714
# Epoch 40/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5887 - val_loss: 3.5366
# Epoch 41/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4909 - val_loss: 2.8110
# Epoch 42/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.5248 - val_loss: 2.4756
# Epoch 43/50
# 2/2 [==============================] - 0s 36ms/step - loss: 3.4981 - val_loss: 2.4306
# Epoch 44/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.5277 - val_loss: 2.3872
# Epoch 45/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5348 - val_loss: 2.3931
# Epoch 46/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5368 - val_loss: 2.4534
# Epoch 47/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5137 - val_loss: 2.5388
# Epoch 48/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4601 - val_loss: 2.6831
# Epoch 49/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4219 - val_loss: 2.9841
# Epoch 50/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.3995 - val_loss: 3.2342

# %%
# Load in best performing model
model = tf.keras.models.load_model("/content/model_experiments/model_5_lstm/")
model.evaluate(test_windows, test_labels)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 175ms/step - loss: 1.8062
# 1.806243896484375

# %%
# Taken from Daniel Bourke GitHub repo for TIme Series BitCoin Prediction
def make_preds(model, input_data):
  """
  Uses model to make predictions on input_data.

  Parameters
  ----------
  model: trained model
  input_data: windowed input data (same kind of data model was trained on)

  Returns model predictions on input_data.
  """
  forecast = model.predict(input_data)
  return tf.squeeze(forecast) # return 1D array of predictions

# %%
# Get forecast predictions
model_preds = make_preds(model,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 164ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([84.66668 , 83.791695, 83.10852 , 82.582664, 81.736336, 84.24413 ,
#        87.27362 , 88.18009 ], dtype=float32)>

# %%
# Evaluate results for model predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels),
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 1.8062439,
#  'mse': 4.932947,
#  'rmse': 2.2210238,
#  'mape': 2.1487632,
#  'mase': 0.6020813}

# %%
naive_results
# Out:
# {'mae': 3.1111112,
#  'mse': 9.777778,
#  'rmse': 3.1269438,
#  'mape': 3.711237,
#  'mase': 0.9955556}

# %%
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Prediction

# %%
# Add windowed columns
lumina_df = lumina.copy()
for i in range(WINDOW_SIZE):
  lumina_df[f"Stock_Price+{i+1}"] = lumina_df["Stock_Price"].shift(periods=i+1)
lumina_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08           56           60.0           55.0           58.0
# 2024-01-09           59           56.0           60.0           55.0
# 2024-01-10           62           59.0           56.0           60.0
# 2024-01-11           65           62.0           59.0           56.0
# 2024-01-12           61           65.0           62.0           59.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08           52.0           57.0           53.0           50.0
# 2024-01-09           58.0           52.0           57.0           53.0
# 2024-01-10           55.0           58.0           52.0           57.0
# 2024-01-11           60.0           55.0           58.0           52.0
# 2024-01-12           56.0           60.0           55.0           58.0

# %%
X = lumina_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = lumina_df.dropna()["Stock_Price"].to_numpy()

# %%
tf.random.set_seed(0)

# Train on entire data
model.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 4s 1s/step - loss: 3.9149 - val_loss: 4.1096
# Epoch 2/50
# 3/3 [==============================] - 1s 699ms/step - loss: 3.6841 - val_loss: 1.6959
# Epoch 3/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.1878 - val_loss: 2.5826
# Epoch 4/50
# 3/3 [==============================] - 2s 837ms/step - loss: 4.2393 - val_loss: 1.3447
# Epoch 5/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9776 - val_loss: 2.5144
# Epoch 6/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.3886 - val_loss: 3.3309
# Epoch 7/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.5398 - val_loss: 1.7305
# Epoch 8/50
# 3/3 [==============================] - 1s 668ms/step - loss: 3.0143 - val_loss: 1.1539
# Epoch 9/50
# 3/3 [==============================] - 0s 17ms/step - loss: 3.0336 - val_loss: 1.1863
# Epoch 10/50
# 3/3 [==============================] - 1s 664ms/step - loss: 3.0867 - val_loss: 1.1052
# Epoch 11/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.9641 - val_loss: 1.1913
# Epoch 12/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9308 - val_loss: 1.3221
# Epoch 13/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.9284 - val_loss: 1.3944
# Epoch 14/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.9394 - val_loss: 1.1128
# Epoch 15/50
# 3/3 [==============================] - 1s 666ms/step - loss: 2.9156 - val_loss: 1.0853
# Epoch 16/50
# 3/3 [==============================] - 0s 20ms/step - loss: 2.8975 - val_loss: 1.1340
# Epoch 17/50
# 3/3 [==============================] - 0s 15ms/step - loss: 3.0261 - val_loss: 1.2122
# Epoch 18/50
# 3/3 [==============================] - 1s 669ms/step - loss: 2.8822 - val_loss: 0.9858
# Epoch 19/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9575 - val_loss: 1.3845
# Epoch 20/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.9754 - val_loss: 1.0557
# Epoch 21/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9778 - val_loss: 1.5558
# Epoch 22/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.9852 - val_loss: 1.0308
# Epoch 23/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8820 - val_loss: 0.9998
# Epoch 24/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.9005 - val_loss: 1.1787
# Epoch 25/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.8984 - val_loss: 1.1351
# Epoch 26/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8399 - val_loss: 1.0471
# Epoch 27/50
# 3/3 [==============================] - 2s 1s/step - loss: 2.8233 - val_loss: 0.9593
# Epoch 28/50
# 3/3 [==============================] - 0s 24ms/step - loss: 2.8621 - val_loss: 1.0001
# Epoch 29/50
# 3/3 [==============================] - 0s 24ms/step - loss: 2.8441 - val_loss: 0.9718
# Epoch 30/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.8054 - val_loss: 0.9964
# Epoch 31/50
# 3/3 [==============================] - 2s 859ms/step - loss: 2.7970 - val_loss: 0.9158
# Epoch 32/50
# 3/3 [==============================] - 1s 668ms/step - loss: 2.8206 - val_loss: 0.8919
# Epoch 33/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.8031 - val_loss: 0.9615
# Epoch 34/50
# 3/3 [==============================] - 0s 20ms/step - loss: 2.8063 - val_loss: 1.0214
# Epoch 35/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8268 - val_loss: 1.0620
# Epoch 36/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8425 - val_loss: 1.0423
# Epoch 37/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.8209 - val_loss: 0.9977
# Epoch 38/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8003 - val_loss: 0.9265
# Epoch 39/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.8224 - val_loss: 1.4839
# Epoch 40/50
# 3/3 [==============================] - 1s 679ms/step - loss: 2.9091 - val_loss: 0.8650
# Epoch 41/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7774 - val_loss: 1.1751
# Epoch 42/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8358 - val_loss: 1.1096
# Epoch 43/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7802 - val_loss: 1.0401
# Epoch 44/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.8009 - val_loss: 1.0446
# Epoch 45/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7562 - val_loss: 0.9352
# Epoch 46/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7361 - val_loss: 0.9896
# Epoch 47/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7845 - val_loss: 0.9586
# Epoch 48/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7864 - val_loss: 1.1391
# Epoch 49/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7902 - val_loss: 0.9199
# Epoch 50/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7558 - val_loss: 1.3323

# %%
INTO_FUTURE = 7

# %%
# Taken from Daniel Bourke GitHub repo for TIme Series BitCoin Prediction
def make_future_forecast(values, model, into_future, window_size=WINDOW_SIZE) -> list:
  """
  Makes future forecasts into_future steps after values ends.

  Returns future forecasts as list of floats.
  """
  # 2. Make an empty list for future forecasts/prepare data to forecast on
  future_forecast = []
  last_window = values[-WINDOW_SIZE:] # only want preds from the last window (this will get updated)

  # 3. Make INTO_FUTURE number of predictions, altering the data which gets predicted on each time
  for _ in range(into_future):

    # Predict on last window then append it again, again, again (model starts to make forecasts on its own forecasts)
    future_pred = model.predict(tf.expand_dims(last_window, axis=0))
    print(f"Predicting on: \n {last_window} -> Prediction: {tf.squeeze(future_pred).numpy()}\n")

    # Append predictions to future_forecast
    future_forecast.append(tf.squeeze(future_pred).numpy())
    # print(future_forecast)

    # Update last window with new pred and get WINDOW_SIZE most recent preds (model was trained on WINDOW_SIZE windows)
    last_window = np.append(last_window, future_pred)[-WINDOW_SIZE:]

  return future_forecast

# %%
def get_future_dates(start_date, into_future, offset=1):
  """
  Returns array of datetime values from ranging from start_date to start_date+horizon.

  start_date: date to start range (np.datetime64)
  into_future: number of days to add onto start date for range (int)
  offset: number of days to offset start_date by (default 1)
  """
  start_date = start_date + np.timedelta64(offset, "D") # specify start date, "D" stands for day
  end_date = start_date + np.timedelta64(into_future, "D") # specify end date
  return np.arange(start_date, end_date, dtype="datetime64[D]") # return a date range between start date and end date

# %%
# Make forecasts into future of the price
future_forecast = make_future_forecast(values=y,
                                       model=model,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 84ms/step
# Predicting on:
#  [88 85 82 79 82 85 88] -> Prediction: 90.48160552978516
#
# 1/1 [==============================] - 0s 145ms/step
# Predicting on:
#  [85.         82.         79.         82.         85.         88.
#  90.48160553] -> Prediction: 89.54833984375
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [82.         79.         82.         85.         88.         90.48160553
#  89.54833984] -> Prediction: 86.47429656982422
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [79.         82.         85.         88.         90.48160553 89.54833984
#  86.47429657] -> Prediction: 84.94109344482422
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [82.         85.         88.         90.48160553 89.54833984 86.47429657
#  84.94109344] -> Prediction: 87.70203399658203
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [85.         88.         90.48160553 89.54833984 86.47429657 84.94109344
#  87.702034  ] -> Prediction: 91.58390045166016
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [88.         90.48160553 89.54833984 86.47429657 84.94109344 87.702034
#  91.58390045] -> Prediction: 94.51753234863281

# %%
# Last timestep of timesteps
last_timestep = lumina.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22'], dtype='datetime64[D]')

# %%
# Insert last timestep/final price
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, lumina["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22'],
#        dtype='datetime64[D]'),
#  array([88.      , 90.481606, 89.54834 , 86.4743  , 84.94109 , 87.702034,
#         91.5839  , 94.51753 ], dtype=float32))

# %% [markdown]
# ### Future Predicitons Plot

# %%
# Plot future price predictions
plt.figure(figsize=(10, 7))
plot_time_series(lumina.index, lumina["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")
plt.xticks(rotation=45)
# Out:
# (array([19723., 19730., 19737., 19744., 19754., 19761., 19768., 19775.]),
#  [Text(19723.0, 0, '2024-01-01'),
#   Text(19730.0, 0, '2024-01-08'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19744.0, 0, '2024-01-22'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19761.0, 0, '2024-02-08'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19775.0, 0, '2024-02-22')])

# %% [markdown]
# ## Nexus

# %%
# Get date array
timesteps = nexus.index.to_numpy()
prices = nexus["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([120, 114, 127, 120, 124, 118, 122, 118, 115, 119]))

# %% [markdown]
# ### Windowing Dataset

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [120 114 127 120 124 118 122] -> Label: [118]
# Window: [114 127 120 124 118 122 118] -> Label: [115]
# Window: [127 120 124 118 122 118 115] -> Label: [119]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1))
print(f"Original shape: {x.shape}")
print(f"Expanded shape: {expand_dims_layer(x).shape}")
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[120]
#  [114]
#  [127]
#  [120]
#  [124]
#  [118]
#  [122]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(0)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs)
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x)
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model2 = tf.keras.Model(inputs=inputs, outputs=output, name="model2")

# Compile model
model2.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Seems when saving the model several warnings are appearing: https://github.com/tensorflow/tensorflow/issues/47554
model2.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model2.name)])
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 2/2 [==============================] - 3s 2s/step - loss: 115.9837 - val_loss: 102.9043
# Epoch 2/50
# 2/2 [==============================] - 2s 2s/step - loss: 113.8273 - val_loss: 100.8591
# Epoch 3/50
# 2/2 [==============================] - 2s 2s/step - loss: 111.7720 - val_loss: 98.8499
# Epoch 4/50
# 2/2 [==============================] - 2s 2s/step - loss: 109.4716 - val_loss: 95.8988
# Epoch 5/50
# 2/2 [==============================] - 1s 1s/step - loss: 105.6750 - val_loss: 90.6992
# Epoch 6/50
# 2/2 [==============================] - 1s 1s/step - loss: 99.2724 - val_loss: 84.1990
# Epoch 7/50
# 2/2 [==============================] - 1s 1s/step - loss: 92.2252 - val_loss: 79.2253
# Epoch 8/50
# 2/2 [==============================] - 2s 2s/step - loss: 87.5056 - val_loss: 76.0368
# Epoch 9/50
# 2/2 [==============================] - 1s 1s/step - loss: 84.4286 - val_loss: 73.4655
# Epoch 10/50
# 2/2 [==============================] - 1s 1s/step - loss: 81.7424 - val_loss: 70.9305
# Epoch 11/50
# 2/2 [==============================] - 2s 2s/step - loss: 79.0161 - val_loss: 68.1682
# Epoch 12/50
# 2/2 [==============================] - 2s 2s/step - loss: 75.8916 - val_loss: 64.7927
# Epoch 13/50
# 2/2 [==============================] - 1s 1s/step - loss: 71.9581 - val_loss: 60.1130
# Epoch 14/50
# 2/2 [==============================] - 2s 2s/step - loss: 66.4884 - val_loss: 53.9696
# Epoch 15/50
# 2/2 [==============================] - 1s 1s/step - loss: 59.7654 - val_loss: 48.2625
# Epoch 16/50
# 2/2 [==============================] - 1s 1s/step - loss: 54.1070 - val_loss: 44.0130
# Epoch 17/50
# 2/2 [==============================] - 1s 1s/step - loss: 49.7845 - val_loss: 40.2215
# Epoch 18/50
# 2/2 [==============================] - 1s 1s/step - loss: 45.7414 - val_loss: 36.4178
# Epoch 19/50
# 2/2 [==============================] - 2s 2s/step - loss: 41.6397 - val_loss: 32.5075
# Epoch 20/50
# 2/2 [==============================] - 2s 2s/step - loss: 37.4043 - val_loss: 28.4757
# Epoch 21/50
# 2/2 [==============================] - 1s 1s/step - loss: 33.0379 - val_loss: 24.3198
# Epoch 22/50
# 2/2 [==============================] - 1s 1s/step - loss: 28.5322 - val_loss: 20.0403
# Epoch 23/50
# 2/2 [==============================] - 1s 1s/step - loss: 23.8987 - val_loss: 15.6370
# Epoch 24/50
# 2/2 [==============================] - 1s 1s/step - loss: 19.1245 - val_loss: 11.1105
# Epoch 25/50
# 2/2 [==============================] - 2s 2s/step - loss: 14.2288 - val_loss: 6.4589
# Epoch 26/50
# 2/2 [==============================] - 1s 1s/step - loss: 9.1941 - val_loss: 2.7127
# Epoch 27/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.3757 - val_loss: 3.4219
# Epoch 28/50
# 2/2 [==============================] - 0s 30ms/step - loss: 3.1846 - val_loss: 7.2778
# Epoch 29/50
# 2/2 [==============================] - 0s 28ms/step - loss: 5.4301 - val_loss: 9.8656
# Epoch 30/50
# 2/2 [==============================] - 0s 29ms/step - loss: 7.4705 - val_loss: 10.8087
# Epoch 31/50
# 2/2 [==============================] - 0s 27ms/step - loss: 8.1256 - val_loss: 10.4551
# Epoch 32/50
# 2/2 [==============================] - 0s 29ms/step - loss: 7.4670 - val_loss: 9.1004
# Epoch 33/50
# 2/2 [==============================] - 0s 28ms/step - loss: 5.8561 - val_loss: 7.0154
# Epoch 34/50
# 2/2 [==============================] - 0s 30ms/step - loss: 4.0354 - val_loss: 4.6464
# Epoch 35/50
# 2/2 [==============================] - 0s 28ms/step - loss: 2.6337 - val_loss: 3.0674
# Epoch 36/50
# 2/2 [==============================] - 1s 1s/step - loss: 2.9603 - val_loss: 2.3701
# Epoch 37/50
# 2/2 [==============================] - 0s 30ms/step - loss: 3.7746 - val_loss: 2.3856
# Epoch 38/50
# 2/2 [==============================] - 0s 46ms/step - loss: 4.2186 - val_loss: 2.3931
# Epoch 39/50
# 2/2 [==============================] - 2s 2s/step - loss: 4.0744 - val_loss: 2.3229
# Epoch 40/50
# 2/2 [==============================] - 0s 43ms/step - loss: 3.4779 - val_loss: 2.5975
# Epoch 41/50
# 2/2 [==============================] - 0s 45ms/step - loss: 2.9574 - val_loss: 3.2938
# Epoch 42/50
# 2/2 [==============================] - 0s 45ms/step - loss: 2.7436 - val_loss: 4.1243
# Epoch 43/50
# 2/2 [==============================] - 0s 37ms/step - loss: 2.9032 - val_loss: 4.8011
# Epoch 44/50
# 2/2 [==============================] - 0s 47ms/step - loss: 3.0948 - val_loss: 4.9122
# Epoch 45/50
# 2/2 [==============================] - 0s 67ms/step - loss: 3.1125 - val_loss: 4.4522
# Epoch 46/50
# 2/2 [==============================] - 0s 47ms/step - loss: 2.8860 - val_loss: 3.9420
# Epoch 47/50
# 2/2 [==============================] - 0s 65ms/step - loss: 2.7915 - val_loss: 3.4183
# Epoch 48/50
# 2/2 [==============================] - 0s 48ms/step - loss: 2.6960 - val_loss: 3.1602
# Epoch 49/50
# 2/2 [==============================] - 0s 64ms/step - loss: 2.7420 - val_loss: 3.0681
# Epoch 50/50
# 2/2 [==============================] - 0s 45ms/step - loss: 2.7933 - val_loss: 3.0920

# %%
# Load in best performing model
model2 = tf.keras.models.load_model("/content/model_experiments/model2/")
model2.evaluate(test_windows, test_labels)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 178ms/step - loss: 2.3229
# 2.3228635787963867

# %%
# Get forecast predictions
model_preds = make_preds(model2,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 168ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([109.0699  , 108.42261 , 108.046906, 106.833084, 106.355286,
#        104.75387 , 102.913734, 102.17904 ], dtype=float32)>

# %%
# Evaluate results for model 2 predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels),
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 2.3228636,
#  'mse': 7.770403,
#  'rmse': 2.7875443,
#  'mape': 2.2120945,
#  'mase': 0.67750186}

# %%
plt.figure(figsize=(10, 7))
# Account for the test_window offset
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Predicition

# %%
# Add windowed columns
nexus_df = nexus.copy()
for i in range(WINDOW_SIZE):
  nexus_df[f"Stock_Price+{i+1}"] = nexus_df["Stock_Price"].shift(periods=i+1)
nexus_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08          118          122.0          118.0          124.0
# 2024-01-09          115          118.0          122.0          118.0
# 2024-01-10          119          115.0          118.0          122.0
# 2024-01-11          123          119.0          115.0          118.0
# 2024-01-12          120          123.0          119.0          115.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08          120.0          127.0          114.0          120.0
# 2024-01-09          124.0          120.0          127.0          114.0
# 2024-01-10          118.0          124.0          120.0          127.0
# 2024-01-11          122.0          118.0          124.0          120.0
# 2024-01-12          118.0          122.0          118.0          124.0

# %%
X = nexus_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = nexus_df.dropna()["Stock_Price"].to_numpy()

# %%
model2.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 3s 913ms/step - loss: 3.2236 - val_loss: 3.5679
# Epoch 2/50
# 3/3 [==============================] - 1s 679ms/step - loss: 3.0093 - val_loss: 2.9004
# Epoch 3/50
# 3/3 [==============================] - 0s 17ms/step - loss: 3.0383 - val_loss: 2.9123
# Epoch 4/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.0154 - val_loss: 3.0827
# Epoch 5/50
# 3/3 [==============================] - 2s 768ms/step - loss: 2.9916 - val_loss: 2.8145
# Epoch 6/50
# 3/3 [==============================] - 2s 999ms/step - loss: 2.9340 - val_loss: 2.7498
# Epoch 7/50
# 3/3 [==============================] - 0s 32ms/step - loss: 2.9581 - val_loss: 2.8652
# Epoch 8/50
# 3/3 [==============================] - 0s 26ms/step - loss: 2.9272 - val_loss: 2.7937
# Epoch 9/50
# 3/3 [==============================] - 0s 28ms/step - loss: 2.7519 - val_loss: 3.4611
# Epoch 10/50
# 3/3 [==============================] - 0s 26ms/step - loss: 2.8615 - val_loss: 3.3204
# Epoch 11/50
# 3/3 [==============================] - 2s 919ms/step - loss: 2.7229 - val_loss: 2.6440
# Epoch 12/50
# 3/3 [==============================] - 0s 31ms/step - loss: 2.9930 - val_loss: 3.1422
# Epoch 13/50
# 3/3 [==============================] - 0s 40ms/step - loss: 2.6369 - val_loss: 3.1452
# Epoch 14/50
# 3/3 [==============================] - 0s 24ms/step - loss: 2.6472 - val_loss: 2.9269
# Epoch 15/50
# 3/3 [==============================] - 0s 25ms/step - loss: 2.6566 - val_loss: 3.0784
# Epoch 16/50
# 3/3 [==============================] - 0s 30ms/step - loss: 2.6110 - val_loss: 2.7296
# Epoch 17/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.7416 - val_loss: 2.9027
# Epoch 18/50
# 3/3 [==============================] - 0s 24ms/step - loss: 2.7227 - val_loss: 3.5317
# Epoch 19/50
# 3/3 [==============================] - 0s 31ms/step - loss: 2.6659 - val_loss: 2.9765
# Epoch 20/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.6962 - val_loss: 2.7476
# Epoch 21/50
# 3/3 [==============================] - 0s 36ms/step - loss: 2.6145 - val_loss: 3.0981
# Epoch 22/50
# 3/3 [==============================] - 0s 24ms/step - loss: 2.6485 - val_loss: 3.4548
# Epoch 23/50
# 3/3 [==============================] - 0s 22ms/step - loss: 2.6789 - val_loss: 3.3417
# Epoch 24/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.8269 - val_loss: 2.8109
# Epoch 25/50
# 3/3 [==============================] - 0s 22ms/step - loss: 2.5500 - val_loss: 3.9776
# Epoch 26/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.8454 - val_loss: 3.0593
# Epoch 27/50
# 3/3 [==============================] - 1s 695ms/step - loss: 2.7123 - val_loss: 2.5611
# Epoch 28/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7223 - val_loss: 3.4164
# Epoch 29/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6937 - val_loss: 2.9049
# Epoch 30/50
# 3/3 [==============================] - 2s 911ms/step - loss: 2.7880 - val_loss: 2.5429
# Epoch 31/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.8524 - val_loss: 2.8599
# Epoch 32/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6288 - val_loss: 2.9487
# Epoch 33/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.5791 - val_loss: 3.3517
# Epoch 34/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6908 - val_loss: 3.0553
# Epoch 35/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.5470 - val_loss: 2.7351
# Epoch 36/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6947 - val_loss: 2.7563
# Epoch 37/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.5347 - val_loss: 3.5091
# Epoch 38/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6662 - val_loss: 2.9396
# Epoch 39/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.5688 - val_loss: 2.8739
# Epoch 40/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.5886 - val_loss: 3.0556
# Epoch 41/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.5942 - val_loss: 3.2016
# Epoch 42/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.6645 - val_loss: 3.6003
# Epoch 43/50
# 3/3 [==============================] - 1s 683ms/step - loss: 2.5982 - val_loss: 2.5296
# Epoch 44/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7341 - val_loss: 3.3233
# Epoch 45/50
# 3/3 [==============================] - 0s 22ms/step - loss: 2.6030 - val_loss: 3.3748
# Epoch 46/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.5774 - val_loss: 2.8596
# Epoch 47/50
# 3/3 [==============================] - 1s 666ms/step - loss: 2.5082 - val_loss: 2.4952
# Epoch 48/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.5785 - val_loss: 2.9796
# Epoch 49/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.4610 - val_loss: 2.9650
# Epoch 50/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.4375 - val_loss: 2.8326

# %%
INTO_FUTURE = 7

# %%
# Make forecasts into future
future_forecast = make_future_forecast(values=y,
                                       model=model2,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Predicting on:
#  [108 105 108 104 100 103 106] -> Prediction: 104.88735961914062
#
# 1/1 [==============================] - 0s 153ms/step
# Predicting on:
#  [105.         108.         104.         100.         103.
#  106.         104.88735962] -> Prediction: 101.83273315429688
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [108.         104.         100.         103.         106.
#  104.88735962 101.83273315] -> Prediction: 102.5048599243164
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [104.         100.         103.         106.         104.88735962
#  101.83273315 102.50485992] -> Prediction: 102.17233276367188
#
# 1/1 [==============================] - 0s 17ms/step
# Predicting on:
#  [100.         103.         106.         104.88735962 101.83273315
#  102.50485992 102.17233276] -> Prediction: 100.53573608398438
#
# 1/1 [==============================] - 0s 21ms/step
# Predicting on:
#  [103.         106.         104.88735962 101.83273315 102.50485992
#  102.17233276 100.53573608] -> Prediction: 100.40927124023438
#
# 1/1 [==============================] - 0s 17ms/step
# Predicting on:
#  [106.         104.88735962 101.83273315 102.50485992 102.17233276
#  100.53573608 100.40927124] -> Prediction: 101.21939086914062

# %%
# Last timestep of timesteps
last_timestep = nexus.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next tweek of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22'], dtype='datetime64[D]')

# %%
# Insert last timestep/final price
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, nexus["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22'],
#        dtype='datetime64[D]'),
#  array([106.      , 104.88736 , 101.83273 , 102.50486 , 102.17233 ,
#         100.535736, 100.40927 , 101.21939 ], dtype=float32))

# %% [markdown]
# ### Future Predicition Plot

# %%
# Plot future price predictions
plt.figure(figsize=(10, 7))
plot_time_series(nexus.index, nexus["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")
plt.xticks(rotation=45)
# Out:
# (array([19723., 19730., 19737., 19744., 19754., 19761., 19768., 19775.]),
#  [Text(19723.0, 0, '2024-01-01'),
#   Text(19730.0, 0, '2024-01-08'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19744.0, 0, '2024-01-22'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19761.0, 0, '2024-02-08'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19775.0, 0, '2024-02-22')])

# %% [markdown]
# ## Quantumize

# %%
# Get date array
timesteps = quantumize.index.to_numpy()
prices = quantumize["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([80, 83, 86, 84, 81, 79, 82, 85, 87, 89]))

# %% [markdown]
# ### Windowing Dataset

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [80 83 86 84 81 79 82] -> Label: [85]
# Window: [83 86 84 81 79 82 85] -> Label: [87]
# Window: [86 84 81 79 82 85 87] -> Label: [89]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1))
print(f"Original shape: {x.shape}")
print(f"Expanded shape: {expand_dims_layer(x).shape}")
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[80]
#  [83]
#  [86]
#  [84]
#  [81]
#  [79]
#  [82]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs)
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x)
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model3 = tf.keras.Model(inputs=inputs, outputs=output, name="model3")

# Compile model
model3.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# fit
model3.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model3.name)])
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 2/2 [==============================] - 3s 2s/step - loss: 85.4751 - val_loss: 85.8746
# Epoch 2/50
# 2/2 [==============================] - 1s 1s/step - loss: 82.7871 - val_loss: 82.8398
# Epoch 3/50
# 2/2 [==============================] - 2s 2s/step - loss: 79.5594 - val_loss: 78.9944
# Epoch 4/50
# 2/2 [==============================] - 1s 1s/step - loss: 75.4118 - val_loss: 74.7508
# Epoch 5/50
# 2/2 [==============================] - 2s 2s/step - loss: 71.0897 - val_loss: 70.8631
# Epoch 6/50
# 2/2 [==============================] - 2s 2s/step - loss: 67.3581 - val_loss: 67.7071
# Epoch 7/50
# 2/2 [==============================] - 1s 1s/step - loss: 64.2888 - val_loss: 64.8317
# Epoch 8/50
# 2/2 [==============================] - 1s 1s/step - loss: 61.2492 - val_loss: 61.5100
# Epoch 9/50
# 2/2 [==============================] - 1s 1s/step - loss: 57.6377 - val_loss: 57.5411
# Epoch 10/50
# 2/2 [==============================] - 2s 2s/step - loss: 53.4031 - val_loss: 53.3594
# Epoch 11/50
# 2/2 [==============================] - 1s 1s/step - loss: 49.2560 - val_loss: 49.3690
# Epoch 12/50
# 2/2 [==============================] - 1s 1s/step - loss: 45.2042 - val_loss: 44.9656
# Epoch 13/50
# 2/2 [==============================] - 2s 2s/step - loss: 40.3539 - val_loss: 38.6628
# Epoch 14/50
# 2/2 [==============================] - 2s 2s/step - loss: 32.9631 - val_loss: 28.3303
# Epoch 15/50
# 2/2 [==============================] - 1s 1s/step - loss: 21.3820 - val_loss: 12.8775
# Epoch 16/50
# 2/2 [==============================] - 2s 2s/step - loss: 7.0910 - val_loss: 4.2257
# Epoch 17/50
# 2/2 [==============================] - 0s 32ms/step - loss: 8.7682 - val_loss: 8.9518
# Epoch 18/50
# 2/2 [==============================] - 0s 31ms/step - loss: 11.0192 - val_loss: 6.8916
# Epoch 19/50
# 2/2 [==============================] - 1s 1s/step - loss: 7.7133 - val_loss: 1.9833
# Epoch 20/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.1973 - val_loss: 3.7976
# Epoch 21/50
# 2/2 [==============================] - 0s 40ms/step - loss: 3.7252 - val_loss: 6.9557
# Epoch 22/50
# 2/2 [==============================] - 0s 29ms/step - loss: 5.2780 - val_loss: 7.8230
# Epoch 23/50
# 2/2 [==============================] - 0s 28ms/step - loss: 5.5122 - val_loss: 6.8806
# Epoch 24/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.6528 - val_loss: 5.1951
# Epoch 25/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.9488 - val_loss: 3.8614
# Epoch 26/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.7226 - val_loss: 3.0800
# Epoch 27/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.9112 - val_loss: 2.9147
# Epoch 28/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.1539 - val_loss: 2.8913
# Epoch 29/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.1950 - val_loss: 2.8294
# Epoch 30/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.0306 - val_loss: 2.7287
# Epoch 31/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7749 - val_loss: 2.8947
# Epoch 32/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.3400 - val_loss: 3.2569
# Epoch 33/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.3673 - val_loss: 3.7445
# Epoch 34/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4283 - val_loss: 3.7601
# Epoch 35/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4163 - val_loss: 3.2676
# Epoch 36/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.1553 - val_loss: 2.4795
# Epoch 37/50
# 2/2 [==============================] - 1s 1s/step - loss: 3.0762 - val_loss: 1.8900
# Epoch 38/50
# 2/2 [==============================] - 1s 1s/step - loss: 3.0888 - val_loss: 1.8657
# Epoch 39/50
# 2/2 [==============================] - 1s 1s/step - loss: 3.1255 - val_loss: 1.8472
# Epoch 40/50
# 2/2 [==============================] - 2s 2s/step - loss: 3.0146 - val_loss: 1.8306
# Epoch 41/50
# 2/2 [==============================] - 0s 57ms/step - loss: 2.7902 - val_loss: 2.0633
# Epoch 42/50
# 2/2 [==============================] - 0s 54ms/step - loss: 2.8649 - val_loss: 2.3206
# Epoch 43/50
# 2/2 [==============================] - 0s 41ms/step - loss: 2.8765 - val_loss: 2.1229
# Epoch 44/50
# 2/2 [==============================] - 2s 2s/step - loss: 2.7319 - val_loss: 1.7951
# Epoch 45/50
# 2/2 [==============================] - 0s 32ms/step - loss: 2.7474 - val_loss: 1.8000
# Epoch 46/50
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7911 - val_loss: 1.7986
# Epoch 47/50
# 2/2 [==============================] - 0s 29ms/step - loss: 2.7616 - val_loss: 1.7967
# Epoch 48/50
# 2/2 [==============================] - 1s 1s/step - loss: 2.7356 - val_loss: 1.7908
# Epoch 49/50
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6480 - val_loss: 1.9536
# Epoch 50/50
# 2/2 [==============================] - 0s 36ms/step - loss: 2.6361 - val_loss: 2.0665

# %%
# Load in best performing model
model3 = tf.keras.models.load_model("/content/model_experiments/model3/")
model3.evaluate(test_windows, test_labels)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 181ms/step - loss: 1.7908
# 1.7907657623291016

# %%
# Get forecast predictions
model_preds = make_preds(model3,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 139ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([78.71696 , 82.06159 , 83.971375, 85.51598 , 83.72935 , 80.31394 ,
#        78.68046 , 78.16368 ], dtype=float32)>

# %%
# Evaluate results for model predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # remove 1 dimension of test labels
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 1.7907658,
#  'mse': 4.446442,
#  'rmse': 2.1086588,
#  'mape': 2.1593695,
#  'mase': 0.7373741}

# %%
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Prediction

# %%
# Add windowed columns
quantumize_df = quantumize.copy()
for i in range(WINDOW_SIZE):
  quantumize_df[f"Stock_Price+{i+1}"] = quantumize_df["Stock_Price"].shift(periods=i+1)
quantumize_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08           85           82.0           79.0           81.0
# 2024-01-09           87           85.0           82.0           79.0
# 2024-01-10           89           87.0           85.0           82.0
# 2024-01-11           92           89.0           87.0           85.0
# 2024-01-12           94           92.0           89.0           87.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08           84.0           86.0           83.0           80.0
# 2024-01-09           81.0           84.0           86.0           83.0
# 2024-01-10           79.0           81.0           84.0           86.0
# 2024-01-11           82.0           79.0           81.0           84.0
# 2024-01-12           85.0           82.0           79.0           81.0

# %%
X = quantumize_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = quantumize_df.dropna()["Stock_Price"].to_numpy()

# %%
model3.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels))
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 36ms/step - loss: 6.3971 - val_loss: 1.7592
# Epoch 2/50
# 3/3 [==============================] - 0s 16ms/step - loss: 5.6184 - val_loss: 2.1202
# Epoch 3/50
# 3/3 [==============================] - 0s 16ms/step - loss: 5.5406 - val_loss: 2.7482
# Epoch 4/50
# 3/3 [==============================] - 0s 15ms/step - loss: 4.7574 - val_loss: 2.7870
# Epoch 5/50
# 3/3 [==============================] - 0s 15ms/step - loss: 3.7723 - val_loss: 4.9560
# Epoch 6/50
# 3/3 [==============================] - 0s 15ms/step - loss: 3.4832 - val_loss: 5.2342
# Epoch 7/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.2478 - val_loss: 5.5948
# Epoch 8/50
# 3/3 [==============================] - 0s 21ms/step - loss: 3.2793 - val_loss: 5.8913
# Epoch 9/50
# 3/3 [==============================] - 0s 17ms/step - loss: 3.1153 - val_loss: 5.8669
# Epoch 10/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.0444 - val_loss: 6.4082
# Epoch 11/50
# 3/3 [==============================] - 0s 15ms/step - loss: 3.1316 - val_loss: 7.0423
# Epoch 12/50
# 3/3 [==============================] - 0s 15ms/step - loss: 3.0687 - val_loss: 5.6220
# Epoch 13/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.8270 - val_loss: 6.1134
# Epoch 14/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.5701 - val_loss: 5.9663
# Epoch 15/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6312 - val_loss: 6.3310
# Epoch 16/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7123 - val_loss: 6.6357
# Epoch 17/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6498 - val_loss: 5.3566
# Epoch 18/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.3946 - val_loss: 5.8457
# Epoch 19/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.4309 - val_loss: 6.0106
# Epoch 20/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7697 - val_loss: 5.8556
# Epoch 21/50
# 3/3 [==============================] - 0s 26ms/step - loss: 2.5410 - val_loss: 4.5529
# Epoch 22/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8804 - val_loss: 6.2814
# Epoch 23/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.3269 - val_loss: 5.3158
# Epoch 24/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.2311 - val_loss: 4.6472
# Epoch 25/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.4919 - val_loss: 4.7755
# Epoch 26/50
# 3/3 [==============================] - 0s 14ms/step - loss: 2.3010 - val_loss: 6.7305
# Epoch 27/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4505 - val_loss: 5.1819
# Epoch 28/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.3658 - val_loss: 4.5499
# Epoch 29/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.3148 - val_loss: 5.0102
# Epoch 30/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.3573 - val_loss: 6.1062
# Epoch 31/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.1970 - val_loss: 5.2745
# Epoch 32/50
# 3/3 [==============================] - 0s 22ms/step - loss: 2.1656 - val_loss: 4.7121
# Epoch 33/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.3834 - val_loss: 5.3491
# Epoch 34/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.1801 - val_loss: 6.0119
# Epoch 35/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.2230 - val_loss: 5.8015
# Epoch 36/50
# 3/3 [==============================] - 0s 20ms/step - loss: 2.5676 - val_loss: 4.7975
# Epoch 37/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.4032 - val_loss: 6.1496
# Epoch 38/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.1476 - val_loss: 5.7535
# Epoch 39/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.0928 - val_loss: 5.9878
# Epoch 40/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.1426 - val_loss: 5.4973
# Epoch 41/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.3983 - val_loss: 5.0205
# Epoch 42/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.0018 - val_loss: 7.3438
# Epoch 43/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.5914 - val_loss: 5.4194
# Epoch 44/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.3577 - val_loss: 4.7148
# Epoch 45/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.1727 - val_loss: 6.4486
# Epoch 46/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.0749 - val_loss: 4.8048
# Epoch 47/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.1865 - val_loss: 4.3894
# Epoch 48/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.2814 - val_loss: 5.9406
# Epoch 49/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.1001 - val_loss: 5.3408
# Epoch 50/50
# 3/3 [==============================] - 0s 15ms/step - loss: 2.2054 - val_loss: 5.0213

# %%
INTO_FUTURE = 7

# %%
future_forecast = make_future_forecast(values=y,
                                       model=model3,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Predicting on:
#  [84 87 85 82 80 78 81] -> Prediction: 84.49359130859375
#
# 1/1 [==============================] - 0s 154ms/step
# Predicting on:
#  [87.         85.         82.         80.         78.         81.
#  84.49359131] -> Prediction: 87.47372436523438
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [85.         82.         80.         78.         81.         84.49359131
#  87.47372437] -> Prediction: 86.86822509765625
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [82.         80.         78.         81.         84.49359131 87.47372437
#  86.8682251 ] -> Prediction: 83.61598205566406
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [80.         78.         81.         84.49359131 87.47372437 86.8682251
#  83.61598206] -> Prediction: 80.92140197753906
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [78.         81.         84.49359131 87.47372437 86.8682251  83.61598206
#  80.92140198] -> Prediction: 78.52323913574219
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [81.         84.49359131 87.47372437 86.8682251  83.61598206 80.92140198
#  78.52323914] -> Prediction: 80.59213256835938

# %%
last_timestep = quantumize.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22'], dtype='datetime64[D]')

# %%
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, quantumize["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22'],
#        dtype='datetime64[D]'),
#  array([81.      , 84.49359 , 87.473724, 86.868225, 83.61598 , 80.9214  ,
#         78.52324 , 80.59213 ], dtype=float32))

# %% [markdown]
# ### Future Prediction Plot

# %%
# Plot future price predictions
plt.figure(figsize=(10, 7))
plot_time_series(quantumize.index, quantumize["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")
plt.xticks(rotation=45)
# Out:
# (array([19723., 19730., 19737., 19744., 19754., 19761., 19768., 19775.]),
#  [Text(19723.0, 0, '2024-01-01'),
#   Text(19730.0, 0, '2024-01-08'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19744.0, 0, '2024-01-22'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19761.0, 0, '2024-02-08'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19775.0, 0, '2024-02-22')])

# %% [markdown]
# ## Synthify

# %%
# Get date array
timesteps = synthify.index.to_numpy()
prices = synthify["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([150, 156, 161, 155, 150, 152, 148, 151, 153, 156]))

# %% [markdown]
# ### Windowing Dataset

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [150 156 161 155 150 152 148] -> Label: [151]
# Window: [156 161 155 150 152 148 151] -> Label: [153]
# Window: [161 155 150 152 148 151 153] -> Label: [156]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1))
print(f"Original shape: {x.shape}")
print(f"Expanded shape: {expand_dims_layer(x).shape}")
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[150]
#  [156]
#  [161]
#  [155]
#  [150]
#  [152]
#  [148]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs)
x = layers.LSTM(64, activation="relu", return_sequences=True)(x)
x = tf.keras.layers.LSTM(32, activation="relu")(x)
x = layers.Dense(16, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model4 = tf.keras.Model(inputs=inputs, outputs=output, name="model4")

# Compile model
model4.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam(0.010))

# model4
model4.fit(train_windows,
            train_labels,
            epochs=100,
            verbose=1,
            batch_size=64,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model4.name)])
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 1/1 [==============================] - 7s 7s/step - loss: 156.8018 - val_loss: 149.5394
# Epoch 2/100
# 1/1 [==============================] - 3s 3s/step - loss: 155.7356 - val_loss: 147.5959
# Epoch 3/100
# 1/1 [==============================] - 2s 2s/step - loss: 153.7507 - val_loss: 136.4970
# Epoch 4/100
# 1/1 [==============================] - 3s 3s/step - loss: 141.8672 - val_loss: 126.1382
# Epoch 5/100
# 1/1 [==============================] - 4s 4s/step - loss: 130.6936 - val_loss: 116.4819
# Epoch 6/100
# 1/1 [==============================] - 2s 2s/step - loss: 120.6200 - val_loss: 100.2402
# Epoch 7/100
# 1/1 [==============================] - 2s 2s/step - loss: 103.0938 - val_loss: 82.8518
# Epoch 8/100
# 1/1 [==============================] - 2s 2s/step - loss: 84.6205 - val_loss: 60.8126
# Epoch 9/100
# 1/1 [==============================] - 4s 4s/step - loss: 61.1035 - val_loss: 32.6872
# Epoch 10/100
# 1/1 [==============================] - 2s 2s/step - loss: 31.0809 - val_loss: 5.5093
# Epoch 11/100
# 1/1 [==============================] - 0s 38ms/step - loss: 6.9602 - val_loss: 25.6405
# Epoch 12/100
# 1/1 [==============================] - 0s 36ms/step - loss: 31.1862 - val_loss: 30.9544
# Epoch 13/100
# 1/1 [==============================] - 0s 36ms/step - loss: 36.8577 - val_loss: 23.7858
# Epoch 14/100
# 1/1 [==============================] - 0s 33ms/step - loss: 29.2026 - val_loss: 8.7434
# Epoch 15/100
# 1/1 [==============================] - 0s 33ms/step - loss: 13.1415 - val_loss: 10.9931
# Epoch 16/100
# 1/1 [==============================] - 0s 34ms/step - loss: 7.4328 - val_loss: 20.3232
# Epoch 17/100
# 1/1 [==============================] - 0s 33ms/step - loss: 17.8719 - val_loss: 23.2108
# Epoch 18/100
# 1/1 [==============================] - 0s 36ms/step - loss: 20.9553 - val_loss: 20.5699
# Epoch 19/100
# 1/1 [==============================] - 0s 34ms/step - loss: 18.1361 - val_loss: 13.0209
# Epoch 20/100
# 1/1 [==============================] - 0s 34ms/step - loss: 10.0766 - val_loss: 5.8905
# Epoch 21/100
# 1/1 [==============================] - 0s 36ms/step - loss: 5.0867 - val_loss: 8.9696
# Epoch 22/100
# 1/1 [==============================] - 0s 34ms/step - loss: 13.4015 - val_loss: 11.1559
# Epoch 23/100
# 1/1 [==============================] - 0s 34ms/step - loss: 15.7354 - val_loss: 7.0295
# Epoch 24/100
# 1/1 [==============================] - 0s 39ms/step - loss: 11.1469 - val_loss: 6.3786
# Epoch 25/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.4462 - val_loss: 11.6660
# Epoch 26/100
# 1/1 [==============================] - 0s 34ms/step - loss: 8.2700 - val_loss: 14.5046
# Epoch 27/100
# 1/1 [==============================] - 0s 35ms/step - loss: 11.6634 - val_loss: 12.7030
# Epoch 28/100
# 1/1 [==============================] - 0s 34ms/step - loss: 9.6792 - val_loss: 8.1778
# Epoch 29/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.7832 - val_loss: 5.7049
# Epoch 30/100
# 1/1 [==============================] - 0s 33ms/step - loss: 6.2532 - val_loss: 6.0496
# Epoch 31/100
# 1/1 [==============================] - 0s 34ms/step - loss: 8.8841 - val_loss: 5.7048
# Epoch 32/100
# 1/1 [==============================] - 0s 34ms/step - loss: 7.2177 - val_loss: 6.5893
# Epoch 33/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3976 - val_loss: 9.6257
# Epoch 34/100
# 1/1 [==============================] - 0s 33ms/step - loss: 6.0509 - val_loss: 11.0437
# Epoch 35/100
# 1/1 [==============================] - 0s 43ms/step - loss: 7.4963 - val_loss: 9.1528
# Epoch 36/100
# 1/1 [==============================] - 0s 32ms/step - loss: 5.6516 - val_loss: 6.5048
# Epoch 37/100
# 1/1 [==============================] - 0s 32ms/step - loss: 4.4120 - val_loss: 5.6995
# Epoch 38/100
# 1/1 [==============================] - 0s 34ms/step - loss: 6.2428 - val_loss: 5.6981
# Epoch 39/100
# 1/1 [==============================] - 0s 35ms/step - loss: 6.3017 - val_loss: 6.2665
# Epoch 40/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.5017 - val_loss: 8.5415
# Epoch 41/100
# 1/1 [==============================] - 0s 35ms/step - loss: 5.1164 - val_loss: 9.7644
# Epoch 42/100
# 1/1 [==============================] - 0s 38ms/step - loss: 6.1760 - val_loss: 8.6809
# Epoch 43/100
# 1/1 [==============================] - 0s 35ms/step - loss: 5.2637 - val_loss: 6.7541
# Epoch 44/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3726 - val_loss: 5.6867
# Epoch 45/100
# 1/1 [==============================] - 0s 34ms/step - loss: 5.5548 - val_loss: 5.6842
# Epoch 46/100
# 1/1 [==============================] - 0s 33ms/step - loss: 6.0300 - val_loss: 6.2406
# Epoch 47/100
# 1/1 [==============================] - 0s 37ms/step - loss: 4.5038 - val_loss: 8.3590
# Epoch 48/100
# 1/1 [==============================] - 0s 36ms/step - loss: 4.9384 - val_loss: 9.4871
# Epoch 49/100
# 1/1 [==============================] - 0s 35ms/step - loss: 5.9356 - val_loss: 8.4151
# Epoch 50/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.9971 - val_loss: 6.3687
# Epoch 51/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.4148 - val_loss: 5.6679
# Epoch 52/100
# 1/1 [==============================] - 0s 33ms/step - loss: 5.6971 - val_loss: 5.7891
# Epoch 53/100
# 1/1 [==============================] - 0s 34ms/step - loss: 5.1600 - val_loss: 6.7355
# Epoch 54/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3551 - val_loss: 7.9757
# Epoch 55/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.6596 - val_loss: 8.2969
# Epoch 56/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.8906 - val_loss: 7.4274
# Epoch 57/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.4242 - val_loss: 6.2392
# Epoch 58/100
# 1/1 [==============================] - 0s 39ms/step - loss: 4.4437 - val_loss: 6.0065
# Epoch 59/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.7786 - val_loss: 6.3678
# Epoch 60/100
# 1/1 [==============================] - 0s 37ms/step - loss: 4.3896 - val_loss: 7.2469
# Epoch 61/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3730 - val_loss: 7.7724
# Epoch 62/100
# 1/1 [==============================] - 0s 42ms/step - loss: 4.5520 - val_loss: 7.5963
# Epoch 63/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.4763 - val_loss: 6.9712
# Epoch 64/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3474 - val_loss: 6.3139
# Epoch 65/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.3839 - val_loss: 6.1423
# Epoch 66/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.5071 - val_loss: 6.8770
# Epoch 67/100
# 1/1 [==============================] - 0s 32ms/step - loss: 4.3338 - val_loss: 7.5551
# Epoch 68/100
# 1/1 [==============================] - 0s 32ms/step - loss: 4.4576 - val_loss: 7.6871
# Epoch 69/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.5070 - val_loss: 7.1200
# Epoch 70/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3405 - val_loss: 6.5127
# Epoch 71/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.3200 - val_loss: 6.1523
# Epoch 72/100
# 1/1 [==============================] - 0s 38ms/step - loss: 4.4330 - val_loss: 6.6280
# Epoch 73/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3041 - val_loss: 7.2427
# Epoch 74/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3480 - val_loss: 7.5048
# Epoch 75/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.4330 - val_loss: 7.2376
# Epoch 76/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3428 - val_loss: 6.6968
# Epoch 77/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2935 - val_loss: 6.1518
# Epoch 78/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.3831 - val_loss: 6.3491
# Epoch 79/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.3186 - val_loss: 6.9044
# Epoch 80/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.2968 - val_loss: 7.3084
# Epoch 81/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3595 - val_loss: 7.1479
# Epoch 82/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3119 - val_loss: 6.6926
# Epoch 83/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2739 - val_loss: 6.1788
# Epoch 84/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3324 - val_loss: 6.1085
# Epoch 85/100
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3646 - val_loss: 6.7645
# Epoch 86/100
# 1/1 [==============================] - 0s 39ms/step - loss: 4.2682 - val_loss: 7.2952
# Epoch 87/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3473 - val_loss: 7.2297
# Epoch 88/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.3238 - val_loss: 6.6203
# Epoch 89/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2488 - val_loss: 6.0423
# Epoch 90/100
# 1/1 [==============================] - 0s 43ms/step - loss: 4.4007 - val_loss: 6.6577
# Epoch 91/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2442 - val_loss: 7.1803
# Epoch 92/100
# 1/1 [==============================] - 0s 36ms/step - loss: 4.3018 - val_loss: 7.0918
# Epoch 93/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2746 - val_loss: 6.6819
# Epoch 94/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2351 - val_loss: 6.2033
# Epoch 95/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.2728 - val_loss: 6.1405
# Epoch 96/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2813 - val_loss: 6.4566
# Epoch 97/100
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2251 - val_loss: 6.8766
# Epoch 98/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.2326 - val_loss: 7.1477
# Epoch 99/100
# 1/1 [==============================] - 0s 33ms/step - loss: 4.2811 - val_loss: 6.8099
# Epoch 100/100
# 1/1 [==============================] - 0s 36ms/step - loss: 4.2209 - val_loss: 6.3937

# %%
# Load in best performing model
model4 = tf.keras.models.load_model("/content/model_experiments/model4")
model4.evaluate(test_windows, test_labels)
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 295ms/step - loss: 5.5093
# 5.509342193603516

# %%
# Get forecast predictions
model_preds = make_preds(model4,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 261ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([155.40784, 152.59744, 150.61205, 151.16315, 151.25269, 152.30687,
#        154.06903, 156.07715], dtype=float32)>

# %%
# Evaluate results for model 2 predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels),
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 5.509342,
#  'mse': 50.370117,
#  'rmse': 7.097191,
#  'mape': 3.762824,
#  'mase': 1.8364474}

# %%
plt.figure(figsize=(10, 7))

plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Predicition

# %%
# Add windowed columns
synthify_df = synthify.copy()
for i in range(WINDOW_SIZE):
  synthify_df[f"Stock_Price+{i+1}"] = synthify_df["Stock_Price"].shift(periods=i+1)
synthify_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08          151          148.0          152.0          150.0
# 2024-01-09          153          151.0          148.0          152.0
# 2024-01-10          156          153.0          151.0          148.0
# 2024-01-11          160          156.0          153.0          151.0
# 2024-01-12          163          160.0          156.0          153.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08          155.0          161.0          156.0          150.0
# 2024-01-09          150.0          155.0          161.0          156.0
# 2024-01-10          152.0          150.0          155.0          161.0
# 2024-01-11          148.0          152.0          150.0          155.0
# 2024-01-12          151.0          148.0          152.0          150.0

# %%
X = synthify_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = synthify_df.dropna()["Stock_Price"].to_numpy()

# %%
model4.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 6s 2s/step - loss: 19.8861 - val_loss: 5.8743
# Epoch 2/50
# 3/3 [==============================] - 0s 20ms/step - loss: 11.2164 - val_loss: 8.3096
# Epoch 3/50
# 3/3 [==============================] - 0s 25ms/step - loss: 7.0519 - val_loss: 6.7195
# Epoch 4/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5.8972 - val_loss: 7.7166
# Epoch 5/50
# 3/3 [==============================] - 3s 2s/step - loss: 6.7098 - val_loss: 5.8113
# Epoch 6/50
# 3/3 [==============================] - 0s 21ms/step - loss: 6.4411 - val_loss: 7.4676
# Epoch 7/50
# 3/3 [==============================] - 0s 21ms/step - loss: 6.8802 - val_loss: 6.8211
# Epoch 8/50
# 3/3 [==============================] - 0s 19ms/step - loss: 6.1351 - val_loss: 8.1237
# Epoch 9/50
# 3/3 [==============================] - 3s 1s/step - loss: 6.2929 - val_loss: 5.7752
# Epoch 10/50
# 3/3 [==============================] - 0s 19ms/step - loss: 7.3056 - val_loss: 8.5258
# Epoch 11/50
# 3/3 [==============================] - 0s 18ms/step - loss: 9.0479 - val_loss: 7.2615
# Epoch 12/50
# 3/3 [==============================] - 0s 18ms/step - loss: 7.1511 - val_loss: 5.8518
# Epoch 13/50
# 3/3 [==============================] - 0s 18ms/step - loss: 8.5057 - val_loss: 14.5637
# Epoch 14/50
# 3/3 [==============================] - 0s 18ms/step - loss: 8.9378 - val_loss: 8.1046
# Epoch 15/50
# 3/3 [==============================] - 0s 18ms/step - loss: 10.0497 - val_loss: 9.3553
# Epoch 16/50
# 3/3 [==============================] - 0s 19ms/step - loss: 7.5692 - val_loss: 6.9158
# Epoch 17/50
# 3/3 [==============================] - 0s 20ms/step - loss: 6.2261 - val_loss: 5.9592
# Epoch 18/50
# 3/3 [==============================] - 0s 18ms/step - loss: 6.1190 - val_loss: 7.5001
# Epoch 19/50
# 3/3 [==============================] - 0s 22ms/step - loss: 5.2256 - val_loss: 5.9788
# Epoch 20/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5.9481 - val_loss: 10.6465
# Epoch 21/50
# 3/3 [==============================] - 0s 18ms/step - loss: 7.2100 - val_loss: 6.4827
# Epoch 22/50
# 3/3 [==============================] - 0s 20ms/step - loss: 5.4417 - val_loss: 6.6289
# Epoch 23/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.5477 - val_loss: 7.7031
# Epoch 24/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.3089 - val_loss: 7.3255
# Epoch 25/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5.6901 - val_loss: 6.6595
# Epoch 26/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.5473 - val_loss: 8.3164
# Epoch 27/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5.9654 - val_loss: 6.1363
# Epoch 28/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5.3727 - val_loss: 9.5295
# Epoch 29/50
# 3/3 [==============================] - 0s 18ms/step - loss: 6.3887 - val_loss: 6.1792
# Epoch 30/50
# 3/3 [==============================] - 0s 23ms/step - loss: 5.9851 - val_loss: 8.6755
# Epoch 31/50
# 3/3 [==============================] - 0s 22ms/step - loss: 6.3214 - val_loss: 6.6988
# Epoch 32/50
# 3/3 [==============================] - 0s 19ms/step - loss: 6.1749 - val_loss: 7.4048
# Epoch 33/50
# 3/3 [==============================] - 0s 18ms/step - loss: 6.0547 - val_loss: 7.5662
# Epoch 34/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.1417 - val_loss: 6.2737
# Epoch 35/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5.9874 - val_loss: 11.0106
# Epoch 36/50
# 3/3 [==============================] - 0s 21ms/step - loss: 8.5122 - val_loss: 6.3091
# Epoch 37/50
# 3/3 [==============================] - 0s 19ms/step - loss: 5.7395 - val_loss: 6.4869
# Epoch 38/50
# 3/3 [==============================] - 0s 28ms/step - loss: 5.2799 - val_loss: 7.5122
# Epoch 39/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.0895 - val_loss: 6.7851
# Epoch 40/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.3762 - val_loss: 10.8203
# Epoch 41/50
# 3/3 [==============================] - 0s 20ms/step - loss: 7.1307 - val_loss: 6.4062
# Epoch 42/50
# 3/3 [==============================] - 0s 18ms/step - loss: 6.1307 - val_loss: 8.8873
# Epoch 43/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.6327 - val_loss: 6.4488
# Epoch 44/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.1152 - val_loss: 7.5050
# Epoch 45/50
# 3/3 [==============================] - 0s 22ms/step - loss: 4.7888 - val_loss: 6.4805
# Epoch 46/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.7474 - val_loss: 8.1711
# Epoch 47/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.6630 - val_loss: 7.0201
# Epoch 48/50
# 3/3 [==============================] - 0s 18ms/step - loss: 4.9777 - val_loss: 9.7407
# Epoch 49/50
# 3/3 [==============================] - 0s 18ms/step - loss: 6.0288 - val_loss: 6.5594
# Epoch 50/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.6406 - val_loss: 7.4142

# %%
INTO_FUTURE = 7

# %%
# Make forecasts into future
future_forecast = make_future_forecast(values=y,
                                       model=model4,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Predicting on:
#  [143 146 149 152 155 158 161] -> Prediction: 150.26693725585938
#
# 1/1 [==============================] - 0s 248ms/step
# Predicting on:
#  [146.         149.         152.         155.         158.
#  161.         150.26693726] -> Prediction: 151.56459045410156
#
# 1/1 [==============================] - 0s 17ms/step
# Predicting on:
#  [149.         152.         155.         158.         161.
#  150.26693726 151.56459045] -> Prediction: 151.25799560546875
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [152.         155.         158.         161.         150.26693726
#  151.56459045 151.25799561] -> Prediction: 152.32659912109375
#
# 1/1 [==============================] - 0s 16ms/step
# Predicting on:
#  [155.         158.         161.         150.26693726 151.56459045
#  151.25799561 152.32659912] -> Prediction: 152.79466247558594
#
# 1/1 [==============================] - 0s 17ms/step
# Predicting on:
#  [158.         161.         150.26693726 151.56459045 151.25799561
#  152.32659912 152.79466248] -> Prediction: 153.3076171875
#
# 1/1 [==============================] - 0s 17ms/step
# Predicting on:
#  [161.         150.26693726 151.56459045 151.25799561 152.32659912
#  152.79466248 153.30761719] -> Prediction: 153.39537048339844

# %%
# Last timestep of timesteps
last_timestep = synthify.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22'], dtype='datetime64[D]')

# %%
# Insert last timestep/final price
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, synthify["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22'],
#        dtype='datetime64[D]'),
#  array([161.     , 150.26694, 151.56459, 151.258  , 152.3266 , 152.79466,
#         153.30762, 153.39537], dtype=float32))

# %% [markdown]
# ### Future Prediction Plot

# %%
# Plot future price predictions
plt.figure(figsize=(10, 7))
plot_time_series(synthify.index, synthify["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")
plt.xticks(rotation=45)
# Out:
# (array([19723., 19730., 19737., 19744., 19754., 19761., 19768., 19775.]),
#  [Text(19723.0, 0, '2024-01-01'),
#   Text(19730.0, 0, '2024-01-08'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19744.0, 0, '2024-01-22'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19761.0, 0, '2024-02-08'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19775.0, 0, '2024-02-22')])

# %% [markdown]
# ## Zenith

# %%
# Get date array
timesteps = zenith.index.to_numpy()
prices = zenith["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([100,  98, 101,  97,  95,  92,  89,  92,  91,  88]))

# %% [markdown]
# ### Windowing Dataset

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [100  98 101  97  95  92  89] -> Label: [92]
# Window: [ 98 101  97  95  92  89  92] -> Label: [91]
# Window: [101  97  95  92  89  92  91] -> Label: [88]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1))
print(f"Original shape: {x.shape}")
print(f"Expanded shape: {expand_dims_layer(x).shape}")
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[100]
#  [ 98]
#  [101]
#  [ 97]
#  [ 95]
#  [ 92]
#  [ 89]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(0)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs)
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x)
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model5 = tf.keras.Model(inputs=inputs, outputs=output, name="model5")

# Compile model
model5.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# fit
model5.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model5.name)])
# Out:
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 2/2 [==============================] - 5s 2s/step - loss: 37.8684 - val_loss: 8.9274
# Epoch 2/50
# 2/2 [==============================] - 1s 1s/step - loss: 35.1021 - val_loss: 7.5973
# Epoch 3/50
# 2/2 [==============================] - 2s 2s/step - loss: 32.5104 - val_loss: 6.3162
# Epoch 4/50
# 2/2 [==============================] - 1s 1s/step - loss: 30.0429 - val_loss: 5.2009
# Epoch 5/50
# 2/2 [==============================] - 1s 1s/step - loss: 27.7368 - val_loss: 4.2029
# Epoch 6/50
# 2/2 [==============================] - 2s 2s/step - loss: 25.2401 - val_loss: 3.3937
# Epoch 7/50
# 2/2 [==============================] - 2s 2s/step - loss: 22.5690 - val_loss: 2.8699
# Epoch 8/50
# 2/2 [==============================] - 1s 1s/step - loss: 19.2850 - val_loss: 2.8520
# Epoch 9/50
# 2/2 [==============================] - 0s 28ms/step - loss: 15.1633 - val_loss: 3.7207
# Epoch 10/50
# 2/2 [==============================] - 0s 30ms/step - loss: 10.4144 - val_loss: 5.3918
# Epoch 11/50
# 2/2 [==============================] - 0s 28ms/step - loss: 5.9831 - val_loss: 7.6232
# Epoch 12/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.8285 - val_loss: 9.5860
# Epoch 13/50
# 2/2 [==============================] - 0s 29ms/step - loss: 5.3541 - val_loss: 10.3221
# Epoch 14/50
# 2/2 [==============================] - 0s 28ms/step - loss: 6.2429 - val_loss: 10.2793
# Epoch 15/50
# 2/2 [==============================] - 0s 35ms/step - loss: 5.5857 - val_loss: 9.8048
# Epoch 16/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.4345 - val_loss: 9.1631
# Epoch 17/50
# 2/2 [==============================] - 0s 35ms/step - loss: 3.7098 - val_loss: 8.5431
# Epoch 18/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7176 - val_loss: 8.0770
# Epoch 19/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.8825 - val_loss: 7.8318
# Epoch 20/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.1126 - val_loss: 7.7365
# Epoch 21/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.1432 - val_loss: 7.8295
# Epoch 22/50
# 2/2 [==============================] - 0s 30ms/step - loss: 4.0402 - val_loss: 8.0102
# Epoch 23/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.9206 - val_loss: 8.3249
# Epoch 24/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.8608 - val_loss: 8.7010
# Epoch 25/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.6772 - val_loss: 8.9563
# Epoch 26/50
# 2/2 [==============================] - 0s 32ms/step - loss: 3.7400 - val_loss: 9.1917
# Epoch 27/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7819 - val_loss: 9.2388
# Epoch 28/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7779 - val_loss: 9.1457
# Epoch 29/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.7472 - val_loss: 8.9229
# Epoch 30/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.6663 - val_loss: 8.7784
# Epoch 31/50
# 2/2 [==============================] - 0s 47ms/step - loss: 3.7014 - val_loss: 8.6346
# Epoch 32/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7162 - val_loss: 8.5918
# Epoch 33/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.7179 - val_loss: 8.6192
# Epoch 34/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.6906 - val_loss: 8.7508
# Epoch 35/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.6723 - val_loss: 8.9421
# Epoch 36/50
# 2/2 [==============================] - 0s 30ms/step - loss: 3.6334 - val_loss: 9.0028
# Epoch 37/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.6447 - val_loss: 9.1201
# Epoch 38/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.6540 - val_loss: 9.1182
# Epoch 39/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.6227 - val_loss: 8.9966
# Epoch 40/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5932 - val_loss: 8.8525
# Epoch 41/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5784 - val_loss: 8.6767
# Epoch 42/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.5793 - val_loss: 8.5894
# Epoch 43/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.5767 - val_loss: 8.5425
# Epoch 44/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.5609 - val_loss: 8.5610
# Epoch 45/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5401 - val_loss: 8.6279
# Epoch 46/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5137 - val_loss: 8.7369
# Epoch 47/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4929 - val_loss: 8.9027
# Epoch 48/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4902 - val_loss: 9.0576
# Epoch 49/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4878 - val_loss: 9.0087
# Epoch 50/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5081 - val_loss: 8.6564

# %%
# Load in best performing model
model5 = tf.keras.models.load_model("/content/model_experiments/model5/")
model5.evaluate(test_windows, test_labels)
# Out:
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 1/1 [==============================] - 0s 181ms/step - loss: 2.8520
# 2.85197377204895

# %%
# Get forecast predictions
model_preds = make_preds(model5,
                           input_data=test_windows)
model_preds[:10]
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b02b6545e10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 166ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([25.009388, 24.5959  , 23.630713, 22.00104 , 20.130892, 18.470837,
#        16.585266, 14.863757], dtype=float32)>

# %%
# Evaluate results for model predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels),
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 2.8519738,
#  'mse': 11.378832,
#  'rmse': 3.3732524,
#  'mape': 20.475908,
#  'mase': 0.9981908}

# %%
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Prediciton

# %%
# Add windowed columns
zenith_df = zenith.copy()
for i in range(WINDOW_SIZE):
  zenith_df[f"Stock_Price+{i+1}"] = zenith_df["Stock_Price"].shift(periods=i+1)
zenith_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08           92           89.0           92.0           95.0
# 2024-01-09           91           92.0           89.0           92.0
# 2024-01-10           88           91.0           92.0           89.0
# 2024-01-11           85           88.0           91.0           92.0
# 2024-01-12           82           85.0           88.0           91.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08           97.0          101.0           98.0          100.0
# 2024-01-09           95.0           97.0          101.0           98.0
# 2024-01-10           92.0           95.0           97.0          101.0
# 2024-01-11           89.0           92.0           95.0           97.0
# 2024-01-12           92.0           89.0           92.0           95.0

# %%
# Make features and labels
X = zenith_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = zenith_df.dropna()["Stock_Price"].to_numpy()

X.shape, y.shape
# Out:
# ((39, 7), (39,))

# %%
model5.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model5.name)])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 4s 1s/step - loss: 14.8118 - val_loss: 4.4858
# Epoch 2/50
# 3/3 [==============================] - 0s 20ms/step - loss: 8.1913 - val_loss: 7.4412
# Epoch 3/50
# 3/3 [==============================] - 0s 18ms/step - loss: 3.6217 - val_loss: 9.6255
# Epoch 4/50
# 3/3 [==============================] - 0s 18ms/step - loss: 4.9392 - val_loss: 9.7027
# Epoch 5/50
# 3/3 [==============================] - 0s 19ms/step - loss: 4.0746 - val_loss: 8.6366
# Epoch 6/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.9785 - val_loss: 7.5320
# Epoch 7/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.9766 - val_loss: 7.0347
# Epoch 8/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9305 - val_loss: 6.9594
# Epoch 9/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.2417 - val_loss: 7.8892
# Epoch 10/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1669 - val_loss: 8.0654
# Epoch 11/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1958 - val_loss: 7.7105
# Epoch 12/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1676 - val_loss: 8.3410
# Epoch 13/50
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0037 - val_loss: 9.1008
# Epoch 14/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8050 - val_loss: 8.8516
# Epoch 15/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0416 - val_loss: 9.7278
# Epoch 16/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8146 - val_loss: 9.8540
# Epoch 17/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.6006 - val_loss: 9.2435
# Epoch 18/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8338 - val_loss: 9.8602
# Epoch 19/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.7407 - val_loss: 9.7492
# Epoch 20/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5572 - val_loss: 8.8519
# Epoch 21/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7672 - val_loss: 9.9742
# Epoch 22/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9045 - val_loss: 9.4064
# Epoch 23/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.7237 - val_loss: 8.7990
# Epoch 24/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5079 - val_loss: 9.5209
# Epoch 25/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7968 - val_loss: 9.0280
# Epoch 26/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7955 - val_loss: 8.6053
# Epoch 27/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7465 - val_loss: 9.8269
# Epoch 28/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6540 - val_loss: 10.1126
# Epoch 29/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6291 - val_loss: 9.9700
# Epoch 30/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.4614 - val_loss: 10.1787
# Epoch 31/50
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3792 - val_loss: 10.3123
# Epoch 32/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.3596 - val_loss: 10.3684
# Epoch 33/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3223 - val_loss: 10.7211
# Epoch 34/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3479 - val_loss: 10.4302
# Epoch 35/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5003 - val_loss: 11.1508
# Epoch 36/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6055 - val_loss: 10.5426
# Epoch 37/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5057 - val_loss: 10.0810
# Epoch 38/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5038 - val_loss: 10.7780
# Epoch 39/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4321 - val_loss: 10.1846
# Epoch 40/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3369 - val_loss: 10.4908
# Epoch 41/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2279 - val_loss: 10.6750
# Epoch 42/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2856 - val_loss: 11.1061
# Epoch 43/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2652 - val_loss: 11.0771
# Epoch 44/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2958 - val_loss: 11.4885
# Epoch 45/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.4079 - val_loss: 10.9045
# Epoch 46/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7056 - val_loss: 10.7978
# Epoch 47/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5396 - val_loss: 11.5049
# Epoch 48/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.6569 - val_loss: 10.4908
# Epoch 49/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4311 - val_loss: 10.7877
# Epoch 50/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3204 - val_loss: 11.1801

# %%
INTO_FUTURE = 7

# %%
# Make forecasts into future of the price
future_forecast = make_future_forecast(values=y,
                                       model=model5,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Predicting on:
#  [26 24 21 18 15 12  9] -> Prediction: 18.36971092224121
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b02b6545e10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 191ms/step
# Predicting on:
#  [24.         21.         18.         15.         12.          9.
#  18.36971092] -> Prediction: 15.976312637329102
#
# 1/1 [==============================] - 0s 19ms/step
# Predicting on:
#  [21.         18.         15.         12.          9.         18.36971092
#  15.97631264] -> Prediction: 13.042473793029785
#
# 1/1 [==============================] - 0s 18ms/step
# Predicting on:
#  [18.         15.         12.          9.         18.36971092 15.97631264
#  13.04247379] -> Prediction: 10.480856895446777
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [15.         12.          9.         18.36971092 15.97631264 13.04247379
#  10.4808569 ] -> Prediction: 7.179547309875488
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [12.          9.         18.36971092 15.97631264 13.04247379 10.4808569
#   7.17954731] -> Prediction: 7.398142337799072
#
# 1/1 [==============================] - 0s 19ms/step
# Predicting on:
#  [ 9.         18.36971092 15.97631264 13.04247379 10.4808569   7.17954731
#   7.39814234] -> Prediction: 8.235963821411133

# %%
# Last timestep of timesteps
last_timestep = zenith.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22'], dtype='datetime64[D]')

# %%
# Insert last timestep/final price
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, zenith["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22'],
#        dtype='datetime64[D]'),
#  array([ 9.       , 18.36971  , 15.976313 , 13.042474 , 10.480857 ,
#          7.1795473,  7.3981423,  8.235964 ], dtype=float32))

# %% [markdown]
# ### Future Prediction Plot

# %%
# Plot future price predictions
plt.figure(figsize=(10, 7))
plot_time_series(zenith.index, zenith["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")
plt.xticks(rotation=45)
# Out:
# (array([19723., 19730., 19737., 19744., 19754., 19761., 19768., 19775.]),
#  [Text(19723.0, 0, '2024-01-01'),
#   Text(19730.0, 0, '2024-01-08'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19744.0, 0, '2024-01-22'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19761.0, 0, '2024-02-08'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19775.0, 0, '2024-02-22')])

# %%
import pandas as pd

data = {
    'ZENITH': [16.54633331298828, 14.088373184204102, 12.748761177062988, 10.00537395477295,8.470556259155273,6.965215682983398,8.507911682128906],
    'SYNTHIFY': [152.56906127929688,  153.78086853027344, 154.7410888671875, 155.29542541503906, 157.0062255859375, 157.33636474609375, 156.7108306884765],
    'QUANTUMIZE': [83.56182098388672, 85.88236999511719,  83.18670654296875, 80.00965118408203, 80.22559356689453, 78.80316925048828, 80.64459228515625],
    'NEXUS': [104.816650390625,102.3831787109375, 102.99588012695312,102.12876892089844,101.01964569091797,101.34393310546875,101.92630004882812],
    'lumina': [90.72627258300781, 89.50856018066406, 84.97201538085938, 83.89037322998047, 87.78638458251953, 92.15631866455078,  94.7286376953125],
}

dates = ['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22']

df = pd.DataFrame(data, index=dates)
df = df.round(2)  # Round to 2 decimal places
df
# Out:
#             ZENITH  SYNTHIFY  QUANTUMIZE   NEXUS  lumina
# 2024-02-16   16.55    152.57       83.56  104.82   90.73
# 2024-02-17   14.09    153.78       85.88  102.38   89.51
# 2024-02-18   12.75    154.74       83.19  103.00   84.97
# 2024-02-19   10.01    155.30       80.01  102.13   83.89
# 2024-02-20    8.47    157.01       80.23  101.02   87.79
# 2024-02-21    6.97    157.34       78.80  101.34   92.16
# 2024-02-22    8.51    156.71       80.64  101.93   94.73

# %%
import pandas as pd

data = {
    'Model': ['Lumina', 'Nexus', 'Quantumize', 'Synthify', 'Zenith'],
    'MAE': [1.8062439, 2.3228636, 1.7907658, 5.509342, 2.8519738],
    'MSE': [4.932947, 7.770403, 4.446442, 50.370117, 11.378832],
    'RMSE': [2.2210238, 2.7875443, 2.1086588, 7.097191, 3.3732524]
}


df = pd.DataFrame(data)
df.to_csv('model_metrics.csv', index=False)
df
# Out:
#         Model       MAE        MSE      RMSE
# 0      Lumina  1.806244   4.932947  2.221024
# 1       Nexus  2.322864   7.770403  2.787544
# 2  Quantumize  1.790766   4.446442  2.108659
# 3    Synthify  5.509342  50.370117  7.097191
# 4      Zenith  2.851974  11.378832  3.373252

# %% [markdown]
# ## Volatality Plots

# %%
def plot_stock_and_volatility(dataframe,name, stock_price_column='Stock_Price', figsize=(10, 7)):
    dataframe['Volatility'] = dataframe[stock_price_column].pct_change().rolling(window=len(dataframe), min_periods=1).std()

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=figsize, sharex=True)

    ax1.plot(dataframe.index, dataframe[stock_price_column], label='Stock Price', color='blue')
    ax1.set_ylabel('Price')
    ax1.set_title(f'{name} Stock Price', fontsize=16)
    ax1.legend(fontsize=12)

    ax2.plot(dataframe.index, dataframe['Volatility'], label='Volatility', color='orange')
    ax2.set_title(f'Volatility Over Time for {name}')
    ax2.set_xlabel('Date')
    ax2.set_ylabel('Volatility')

    ax2.tick_params(axis='x', rotation=45)

    ax2.legend(fontsize=12)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Synthify

# %%
plot_stock_and_volatility(synthify,"synthify")

# %% [markdown]
# ### Nexus

# %%
plot_stock_and_volatility(nexus,"nexus")

# %% [markdown]
# ### Quantumize

# %%
plot_stock_and_volatility(quantumize,"quantumize")

# %% [markdown]
# ## Prediction Analysis

# %%
import pandas as pd

data = {
    'ZENITH': [16.54633331298828, 14.088373184204102, 12.748761177062988, 10.00537395477295,8.470556259155273,6.965215682983398,8.507911682128906],
    'SYNTHIFY': [152.56906127929688,  153.78086853027344, 154.7410888671875, 155.29542541503906, 157.0062255859375, 157.33636474609375, 156.7108306884765],
    'QUANTUMIZE': [83.56182098388672, 85.88236999511719,  83.18670654296875, 80.00965118408203, 80.22559356689453, 78.80316925048828, 80.64459228515625],
    'NEXUS': [104.816650390625,102.3831787109375, 102.99588012695312,102.12876892089844,101.01964569091797,101.34393310546875,101.92630004882812],
    'lumina': [90.72627258300781, 89.50856018066406, 84.97201538085938, 83.89037322998047, 87.78638458251953, 92.15631866455078,  94.7286376953125],
}

dates = ['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22']

df = pd.DataFrame(data, index=dates)
df = df.round(2)  # Round to 2 decimal places
df
# Out:
#             ZENITH  SYNTHIFY  QUANTUMIZE   NEXUS  lumina
# 2024-02-16   16.55    152.57       83.56  104.82   90.73
# 2024-02-17   14.09    153.78       85.88  102.38   89.51
# 2024-02-18   12.75    154.74       83.19  103.00   84.97
# 2024-02-19   10.01    155.30       80.01  102.13   83.89
# 2024-02-20    8.47    157.01       80.23  101.02   87.79
# 2024-02-21    6.97    157.34       78.80  101.34   92.16
# 2024-02-22    8.51    156.71       80.64  101.93   94.73

# %% [markdown]
# ### Correlation Matrix

# %%
import seaborn as sns
plt.figure(figsize=(4, 3))
heatmap = sns.heatmap(df.corr(), annot=True)

heatmap.set_xticklabels(heatmap.get_yticklabels(), rotation=45)

plt.show()

# %% [markdown]
# ### Line Plot with Uncertainty

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# five companies
companies = ['ZENITH', 'SYNTHIFY', 'QUANTUMIZE', 'NEXUS', 'lumina']
days = [1, 2, 3, 4, 5, 6, 7]


# Create subplots
fig = make_subplots(rows=5, cols=1, shared_xaxes=True, subplot_titles=companies, vertical_spacing=0.1)

# Populate each subplot
for i, company in enumerate(companies):
    # Plot predicted prices
    fig.add_trace(go.Scatter(x=days, y=data[company], mode='lines', name='Predicted Prices'), row=i+1, col=1)

    # Add a shaded region to represent uncertainty
    fig.add_trace(go.Scatter(x=days + days[::-1],
                             y=[value + 5 for value in data[company]] + [value - 5 for value in data[company][::-1]],
                             fill='toself',
                             fillcolor='rgba(0,100,80,0.2)',
                             line=dict(color='rgba(255,255,255,0)'),
                             showlegend=False), row=i+1, col=1)

# better visualization
fig.update_layout(title='Predicted Stock Prices with Uncertainty',
                  xaxis_title='Days',
                  template='plotly_dark',
                  height=1200,  # Adjust the height of the entire plot
                  showlegend=True)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="09524bd5-ac4b-4373-ad02-208d8a7133ac" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09524bd5-ac4b-4373-ad02-208d8a7133ac")) {                    Plotly.newPlot(                        "09524bd5-ac4b-4373-ad02-208d8a7133ac",                        [{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[16.54633331298828,14.088373184204102,12.748761177062988,10.00537395477295,8.470556259155273,6.965215682983398,8.507911682128906],"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[21.54633331298828,19.0883731842041,17.74876117706299,15.00537395477295,13.470556259155273,11.965215682983398,13.507911682128906,3.5079116821289062,1.9652156829833984,3.4705562591552734,5.005373954772949,7.748761177062988,9.088373184204102,11.546333312988281],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[152.56906127929688,153.78086853027344,154.7410888671875,155.29542541503906,157.0062255859375,157.33636474609375,156.7108306884765],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[157.56906127929688,158.78086853027344,159.7410888671875,160.29542541503906,162.0062255859375,162.33636474609375,161.7108306884765,151.7108306884765,152.33636474609375,152.0062255859375,150.29542541503906,149.7410888671875,148.78086853027344,147.56906127929688],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[83.56182098388672,85.88236999511719,83.18670654296875,80.00965118408203,80.22559356689453,78.80316925048828,80.64459228515625],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[88.56182098388672,90.88236999511719,88.18670654296875,85.00965118408203,85.22559356689453,83.80316925048828,85.64459228515625,75.64459228515625,73.80316925048828,75.22559356689453,75.00965118408203,78.18670654296875,80.88236999511719,78.56182098388672],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[104.816650390625,102.3831787109375,102.99588012695312,102.12876892089844,101.01964569091797,101.34393310546875,101.92630004882812],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[109.816650390625,107.3831787109375,107.99588012695312,107.12876892089844,106.01964569091797,106.34393310546875,106.92630004882812,96.92630004882812,96.34393310546875,96.01964569091797,97.12876892089844,97.99588012695312,97.3831787109375,99.816650390625],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[90.72627258300781,89.50856018066406,84.97201538085938,83.89037322998047,87.78638458251953,92.15631866455078,94.7286376953125],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[95.72627258300781,94.50856018066406,89.97201538085938,88.89037322998047,92.78638458251953,97.15631866455078,99.7286376953125,89.7286376953125,87.15631866455078,82.78638458251953,78.89037322998047,79.97201538085938,84.50856018066406,85.72627258300781],"type":"scatter","xaxis":"x5","yaxis":"y5"}],       ...

# %% [markdown]
# ### Pie Chart (Budget Allocation)

# %%
import plotly.express as px
import numpy as np

# five companies
companies = ['ZENITH', 'SYNTHIFY', 'QUANTUMIZE', 'NEXUS', 'lumina']


# Example budget
budget = 100

# mean of predicted values over 7 days
mean_values = {company: np.mean(values) for company, values in data.items()}

# Define modification factors (penalty for underperforming, award for well-performing)
modification_factors = {'ZENITH': -5, 'QUANTUMIZE': 5, 'lumina': -5, 'SYNTHIFY': 0, 'NEXUS': 5}

# Apply modification factors to adjust mean values
adjusted_mean_values = {company: mean_value + modification_factors.get(company, 0) for company, mean_value in mean_values.items()}

# Manually adjust the values to meet the desired hierarchy
adjusted_mean_values['QUANTUMIZE'] += 15
adjusted_mean_values['NEXUS'] += 2
adjusted_mean_values['SYNTHIFY'] += 1
adjusted_mean_values['ZENITH'] += 30
adjusted_mean_values['lumina'] -= 35

# Calculate the allocation based on the adjusted mean values
allocation = {company: adjusted_mean_value / sum(adjusted_mean_values.values()) * budget for company, adjusted_mean_value in adjusted_mean_values.items()}

# Create a pie chart
fig = px.pie(values=list(allocation.values()), names=list(allocation.keys()), title='Budget Allocation (Adjusted Mean with Penalties and Awards)')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b49467c7-1752-479f-8130-ae79950c7fc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b49467c7-1752-479f-8130-ae79950c7fc8")) {                    Plotly.newPlot(                        "b49467c7-1752-479f-8130-ae79950c7fc8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["ZENITH","SYNTHIFY","QUANTUMIZE","NEXUS","lumina"],"legendgroup":"","name":"","showlegend":true,"values":[7.963862302316585,34.54159694700906,22.481326338183294,24.16354098490217,10.849673427588886],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"sc ...
